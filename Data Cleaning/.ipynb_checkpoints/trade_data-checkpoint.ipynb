# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("trade_bgd.csv")
df
# Out:
#        Country Name   Country ISO3        Year  \
# 0     #country+name  #country+code  #date+year
# 1        Bangladesh            BGD        2022
# 2        Bangladesh            BGD        2021
# 3        Bangladesh            BGD        2020
# 4        Bangladesh            BGD        2019
# ...             ...            ...         ...
# 5135     Bangladesh            BGD        1980
# 5136     Bangladesh            BGD        1979
# 5137     Bangladesh            BGD        1978
# 5138     Bangladesh            BGD        1977
# 5139     Bangladesh            BGD        1976
#
#                                          Indicator Name     Indicator Code  \
# 0                                       #indicator+name    #indicator+code
# 1                          Trade in services (% of GDP)  BG.GSR.NFSV.GD.ZS
# 2                          Trade in services (% of GDP)  BG.GSR.NFSV.GD.ZS
# 3                          Trade in services (% of GDP)  BG.GSR.NFSV.GD.ZS
# ...
